# %% [markdown]
# # Assignment: Data Wrangling
# ## `! git clone https://github.com/DS3001/wrangling`
# ## Do Q2, and one of Q1 or Q3.

# %%
! git clone https://github.com/DS3001/wrangling
# Out:
# Cloning into 'wrangling'...
# remote: Enumerating objects: 92, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 92 (delta 42), reused 18 (delta 18), pack-reused 40 (from 1)
# Receiving objects: 100% (92/92), 18.08 MiB | 6.82 MiB/s, done.
# Resolving deltas: 100% (43/43), done.

# %% [markdown]
# **Q1.** Open the "tidy_data.pdf" document in the repo, which is a paper called Tidy Data by Hadley Wickham.
#
#   1. Read the abstract. What is this paper about?
#   2. Read the introduction. What is the "tidy data standard" intended to accomplish?
#   3. Read the intro to section 2. What does this sentence mean: "Like families, tidy datasets are all alike but every messy dataset is messy in its own way." What does this sentence mean: "For a given dataset, it’s usually easy to figure out what are observations and what are variables, but it is surprisingly difficult to precisely define variables and observations in general."
#   4. Read Section 2.2. How does Wickham define values, variables, and observations?
#   5. How is "Tidy Data" defined in section 2.3?
#   6. Read the intro to Section 3 and Section 3.1. What are the 5 most common problems with messy datasets? Why are the data in Table 4 messy? What is "melting" a dataset?
#   7. Why, specifically, is table 11 messy but table 12 tidy and "molten"?
#   8. Read Section 6. What is the "chicken-and-egg" problem with focusing on tidy data? What does Wickham hope happens in the future with further work on the subject of data wrangling?

# %% [markdown]
# **Q2.** This question provides some practice cleaning variables which have common problems.
# 1. Numeric variable: For `./data/airbnb_hw.csv`, clean the `Price` variable as well as you can, and explain the choices you make. How many missing values do you end up with? (Hint: What happens to the formatting when a price goes over 999 dollars, say from 675 to 1,112?)
# 2. Categorical variable: For the `./data/sharks.csv` data covered in the lecture, clean the "Type" variable as well as you can, and explain the choices you make.
# 3. Dummy variable: For the pretrial data covered in the lecture, clean the `WhetherDefendantWasReleasedPretrial` variable as well as you can, and, in particular, replace missing values with `np.nan`.
# 4. Missing values, not at random: For the pretrial data covered in the lecture, clean the `ImposedSentenceAllChargeInContactEvent` variable as well as you can, and explain the choices you make. (Hint: Look at the `SentenceTypeAllChargesAtConvictionInContactEvent` variable.)

# %%
import pandas as pd
import numpy as np
airbnb = pd.read_csv("wrangling/assignment/data/airbnb_hw.csv")
print( airbnb.shape, '\n')
# Out:
# (30478, 13)

# %%
airbnb.isna().sum()
# Out:
# Host Id                          0
# Host Since                       3
# Name                             0
# Neighbourhood                    0
# Property Type                    3
# Review Scores Rating (bin)    8323
# Room Type                        0
# Zipcode                        134
# Beds                            85
# Number of Records                0
# Number Of Reviews                0
# Price                            0
# Review Scores Rating          8323
# dtype: int64

# %%
airbnb.isnull().sum()
# Out:
# Host Id                          0
# Host Since                       3
# Name                             0
# Neighbourhood                    0
# Property Type                    3
# Review Scores Rating (bin)    8323
# Room Type                        0
# Zipcode                        134
# Beds                            85
# Number of Records                0
# Number Of Reviews                0
# Price                            0
# Review Scores Rating          8323
# dtype: int64

# %%
price = airbnb['Price']
price.unique()
# Out:
# array(['145', '37', '28', '199', '549', '149', '250', '90', '270', '290',
#        '170', '59', '49', '68', '285', '75', '100', '150', '700', '125',
#        '175', '40', '89', '95', '99', '499', '120', '79', '110', '180',
#        '143', '230', '350', '135', '85', '60', '70', '55', '44', '200',
#        '165', '115', '74', '84', '129', '50', '185', '80', '190', '140',
#        '45', '65', '225', '600', '109', '1,990', '73', '240', '72', '105',
#        '155', '160', '42', '132', '117', '295', '280', '159', '107', '69',
#        '239', '220', '399', '130', '375', '585', '275', '139', '260',
#        '35', '133', '300', '289', '179', '98', '195', '29', '27', '39',
#        '249', '192', '142', '169', '1,000', '131', '138', '113', '122',
#        '329', '101', '475', '238', '272', '308', '126', '235', '315',
#        '248', '128', '56', '207', '450', '215', '210', '385', '445',
#        '136', '247', '118', '77', '76', '92', '198', '205', '299', '222',
# ...

# %% [markdown]
# This is imported as a string since there was a comma in values that are over 1000, so we should converted it to a numeric/float value.

# %%
Price = airbnb['Price']
Price = Price.str.replace(',','')
Price = pd.to_numeric(price,errors='coerce')
print( price.unique() , '\n')
# Out:
# [  145    37    28   199   549   149   250    90   270   290   170    59
#     49    68   285    75   100   150   700   125   175    40    89    95
#     99   499   120    79   110   180   143   230   350   135    85    60
#     70    55    44   200   165   115    74    84   129    50   185    80
#    190   140    45    65   225   600   109  1990    73   240    72   105
#    155   160    42   132   117   295   280   159   107    69   239   220
#    399   130   375   585   275   139   260    35   133   300   289   179
#     98   195    29    27    39   249   192   142   169  1000   131   138
#    113   122   329   101   475   238   272   308   126   235   315   248
#    128    56   207   450   215   210   385   445   136   247   118    77
#     76    92   198   205   299   222   245   104   153   349   114   320
#    292   226   420   500   325   307    78   265   108   123   189    32
#     58    86   219   800   335    63   229   425    67    87  1200   158
# ...

# %%
sharks = pd.read_csv("wrangling/assignment/data/sharks.csv")
sharks.head()
# Out:
# <ipython-input-6-9988a73347ac>:1: DtypeWarning: Columns (10,17,18,19,20,21,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   sharks = pd.read_csv("wrangling/assignment/data/sharks.csv")
#    index   Case Number                  Date    Year        Type      Country  \
# 0      0    2020.02.05           05-Feb-2020  2020.0  Unprovoked          USA
# 1      1  2020.01.30.R  Reported 30-Jan-2020  2020.0    Provoked      BAHAMAS
# 2      2    2020.01.17           17-Jan-2020  2020.0  Unprovoked    AUSTRALIA
# 3      3    2020.01.16           16-Jan-2020  2020.0  Unprovoked  NEW ZEALAND
# 4      4    2020.01.13           13-Jan-2020  2020.0  Unprovoked          USA
#
#               Area               Location                  Activity  \
# 0             Maui                    NaN  Stand-Up Paddle boarding
# 1           Exumas                    NaN                  Floating
# 2  New South Wales          Windang Beach                   Surfing
# ...

# %%
sharks['Type'].value_counts()
# Out:
# Type
# Unprovoked             4716
# Provoked                593
# Invalid                 552
# Sea Disaster            239
# Watercraft              142
# Boat                    109
# Boating                  92
# Questionable             10
# Unconfirmed               1
# Unverified                1
# Under investigation       1
# Boatomg                   1
# Name: count, dtype: int64

# %%
vector=sharks['Type']
vector=vector.replace(['Sea Disaster', 'Boat','Boating','Boatomg'],'Watercraft')
vector.value_counts()
# Out:
# Type
# Unprovoked             4716
# Provoked                593
# Watercraft              583
# Invalid                 552
# Questionable             10
# Unconfirmed               1
# Unverified                1
# Under investigation       1
# Name: count, dtype: int64

# %%
vector = vector.replace(['Invalid', 'Questionable','Unconfirmed','Unverified','Under investigation'],np.nan)
vector.value_counts()
# Out:
# Type
# Unprovoked    4716
# Provoked       593
# Watercraft     583
# Name: count, dtype: int64

# %%
sharks['Type'] = vector

# %% [markdown]
# in the "Type" column of the dataset, there are many miscellaneous catagories, such as unverified, unconfirmned, invalid, etc. To clean these it is impiortent to remove and consolodiate catagories. I removed all types that were not catagoried (ie. unconfirmed, under investigation). I also consolidated all types that had to do with a boat under watercraft. This makes the dataset much easier to analyze.

# %%
pretrial = pd.read_csv("wrangling/pretrial_data.csv")
pretrial.head()
# Out:
# <ipython-input-44-3816c380ebe4>:1: DtypeWarning: Columns (2,5,6,8,80,81,82,83,84,85,109,164,165,166,167,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,238,239,240,241,242,243,244,245,246,247,248,249,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,271,272,273,274,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,302,303,304,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,367,368,369,370,371,372,373,374,375,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,39
# ...

# %%
pretrial = pd.read_csv('./data/VirginiaPretrialData2017.csv', low_memory=False)
pretrial.head()
pretrial.columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-bb195bd46f1e> in <cell line: 1>()
# ----> 1 df = pd.read_csv('./data/VirginiaPretrialData2017.csv', low_memory=False)
#       2 df.head()
#       3 df.columns.tolist()
#
# ...

# %%
release = pretrial['WhetherDefendantWasReleasedPretrial']
print(release.unique(),'\n')
print(release.value_counts(),'\n')
release = release.replace(9,np.nan)
print(release.value_counts(),'\n')
sum(release.isnull())
df['WhetherDefendantWasReleasedPretrial'] = release
del release
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-83c39059f53f> in <cell line: 1>()
# ----> 1 release = pretrial['WhetherDefendantWasReleasedPretrial']
#
# NameError: name 'pretrial' is not defined

# %%
length = pretrial['ImposedSentenceAllChargeInContactEvent']
type = pretrial['SentenceTypeAllChargesAtConvictionInContactEvent']
length = pd.to_numeric(length,errors='coerce')
length_NA = length.isnull()
print( np.sum(length_NA),'\n')
print( pd.crosstab(length_NA, type), '\n')
length = length.mask( type == 4, 0)
length = length.mask( type == 9, np.nan)
length_NA = length.isnull()
print( pd.crosstab(length_NA, type), '\n')
print( np.sum(length_NA),'\n')
pretrial['ImposedSentenceAllChargeInContactEvent'] = length
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-9ae418e66fb3> in <cell line: 1>()
# ----> 1 length = pretrial['ImposedSentenceAllChargeInContactEvent']
#       2 type = pretrial['SentenceTypeAllChargesAtConvictionInContactEvent']
#       3 length = pd.to_numeric(length,errors='coerce')
#       4 length_NA = length.isnull()
#       5 print( np.sum(length_NA),'\n')
#
# NameError: name 'pretrial' is not defined

# %% [markdown]
# Question 1

# %% [markdown]
# 1) The abstract is about a small component of data cleaning called "data tidying" which has a couple of key compnents. These include having iterable datasets which can easily be converted, handle inputs and outputs easily, and each have rows and columns. The general idea is that by having datasets that are tidy and standrdized it will make the data cleaning process more efficient.

# %% [markdown]
# 2)The introduction introduces what the process of data tidying really is and where it fits into data cleaning. Essentially, it is a procedure or method to go about cleaning data that is standardizable and reproducable. In theory, this makes data cleaning easier since everyone can do do it in a similar was and get to a similar result with easy and concice steps to follow.

# %% [markdown]
# 3)The first sentence implies that all data have their own unique problems to solve and the goal is to have clean data which can all be referenced in a similar was (data tidying). The secound sentance is saying that it is easy to take variables at face value, but often hard to figure out what is actually being said. For examplem it is easy to read off the headers of a dataframe and see what the variable is saying, however, it is not always easy to understand what context the variables exist in (what they really mean or imply), especially if the dataset was created or written by another person.

# %% [markdown]
# 4)Wickham defines values as either numeric or catagorical expressions of data, a collection of variables is a value that is identifying the same trait, and an observation is a group of these values that link back to specific variables.

# %% [markdown]
# 5)In tidy language, all of the variables are columns and each row represents a single observation for a single variable. These come together to make tidy tables.

# %% [markdown]
# 6) The five most common problems with datasets are
# -column headers are values (like a year) and not variable names
# -multiple variables in one colums
# -variables stored in olumns and rows
# -multiple types of observational units int he same table
# -single observational unit in multiple tables
#
# Melting a dataset is turning columns into rows in order to tidy it
# In the table 4, we are missing an income variable as a column so we should add one (its hidden in other columns)

# %% [markdown]
# 7)Table 11 is not tidy (messy) becasue it hays days in the top which are technically values. 12 cnanges this into a date varibale which is molten. However, the tmin and tmax still are not tidy becasue they exist in the same day. All the items in 12b are not this trend of variable names so it is "molten" and tidy.

# %% [markdown]
# 8)Wickham describes the chicken and egg problem as an idea that tidy tools will only by linked to tidy data and can create a "local maxima". This would be a world where changing tools or data structure would not imporve workflow. He hopes to see a broader change in the data cleaning process, where data cleaning becomes more of a widespread philosophy and not just used as a necessary evil for people to learn. He hopes it can become more engrained as a system within data science.
